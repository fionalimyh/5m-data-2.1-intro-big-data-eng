# %% [markdown]
# # Assignment

# %% [markdown]
# ## Brief
#
# Write the Python codes for the following questions.

# %% [markdown]
# ## Instructions
#
# - Step 1: Run the followings cell to get connected to your MongoDB. Make sure your credential is in dotenv file.
# - Step 2: Put your answer inside each function. Please do not construct your own function.
# - Step 3: You can test your function under test section.
# - Step 4. Run test my function to confirm if my code is working.

# %% [markdown]
# ### Connections

# %%
import os

from dotenv import load_dotenv
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd
import numpy as np

print("All imported")
# Out:
# All imported

# %%
# Load environment variables from .env file
load_dotenv()
MONGODB_URI = os.getenv("MONGODB_URI")
if not MONGODB_URI:
    raise ValueError(
        "❌ MONGODB_URI not found!\n"
        "Please create a .env file with your MongoDB credentials.\n"
        "See README.md for setup instructions."
    )
client = MongoClient(MONGODB_URI, server_api=ServerApi("1"))
# Send a ping to confirm a successful connection
try:
    client.admin.command("ping")
    print("✅ Successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# ✅ Successfully connected to MongoDB!

# %%
db = client.sample_mflix
movies = db.movies
print(f"📊 Database: {movies}")
print(f"📊 Database: {db.name}")
print(f"📁 Collection: movies ({movies.count_documents({})} documents)")
# Out:
# 📊 Database: Collection(Database(MongoClient(host=['ac-qwuu3oq-shard-00-01.joaa8sc.mongodb.net:27017', 'ac-qwuu3oq-shard-00-00.joaa8sc.mongodb.net:27017', 'ac-qwuu3oq-shard-00-02.joaa8sc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-3kaeqi-shard-0', tls=True, server_api=<pymongo.server_api.ServerApi object at 0x7374e44fc190>), 'sample_mflix'), 'movies')
# 📊 Database: sample_mflix
# 📁 Collection: movies (21352 documents)

# %% [markdown]
# ### Question 1
#
# Question: From the `movies` collection, return the documents with the `plot` that starts with `"war"` in acending order of released date, print only title, plot and released fields. Limit the result to 5.

# %% [markdown]
# **Answer:**

# %% [markdown]
# > Uses `find()` with `$regex` (like SQL `WHERE plot LIKE 'war%'`), chained with `.sort()` ascending and `.limit(5)` — same pattern as the lesson's spy-movie and "Once upon a time" examples.

# %%
import pymongo

for m in movies.find(
    {"plot": {"$regex": "^war", "$options":"i"}}
    ).sort('released', pymongo.ASCENDING).limit(10):

    print(f"Title: {m['title']}\nPlot:{m['plot']}.\nReleased in {m['released']}\n\n")
# Out:
# Title: Nausicaè of the Valley of the Wind
# Plot:Warrior/pacifist Princess Nausicaè desperately struggles to prevent two warring nations from destroying themselves and their dying planet..
# Released in 1984-03-11 00:00:00
#
#
# Title: Nausicaè of the Valley of the Wind
# Plot:Warrior/pacifist Princess Nausicaè desperately struggles to prevent two warring nations from destroying themselves and their dying planet..
# Released in 1984-03-11 00:00:00
#
#
# Title: Heaven and Earth
# Plot:Warlords Kagetora and Takeda each wish to prevent the other from gaining hegemony in feudal Japan. The two samurai leaders pursue one another across the countryside, engaging in massive ....
# Released in 1991-02-08 00:00:00
#
#
# Title: Under the Stars
# Plot:Warning! This synopsis contains spoilers Bajo las estrellas (beneath the stars) features the selfish....
# Released in 2007-06-15 00:00:00
#
#
# Title: Aliens vs. Predator: Requiem
# Plot:Warring alien and predator races descend on a small town, where unsuspecting residents must band together for any chance of survival..
# Released in 2007-12-25 00:00:00
#
#
# Title: Balibo
# Plot:War correspondent Roger East and the young Jose Ramos-Horta travel to East Timor to investigate the murders of the Balibo Five in 1975..
# Released in 2009-08-13 00:00:00
#
#
# Title: Blue Gold: World Water Wars
# Plot:Wars of the future will be fought over water as they are over oil today, as the source of human survival enters the global marketplace and political arena. Corporate giants, private ....
# Released in 2010-01-16 00:00:00
#
#
# Title: Canopy
# Plot:Wartime, 1942. Singapore. An Australian fighter pilot shot down in combat awakens suspended in the treetops. As night devours day, he must navigate through dangerous jungle in search of ....
# Released in 2014-04-24 00:00:00

# %% [markdown]
# ### Question 2
#
# Question: Group by `rated` and count the number of movies in each.

# %% [markdown]
# **Answer:**

# %% [markdown]
# > `$group` is the MongoDB equivalent of SQL `GROUP BY rated, COUNT(*)`. The `$sum: 1` accumulator counts one document per group.

# %%
group_rated = {
   "$group": { # grp movies by the "rated" category
         "_id": "$rated",
         # count the number of movies in each category, for loop to add 1
         "Movie count": { "$sum": 1 }, 
   }
}

pipeline = [group_rated]
results = movies.aggregate(pipeline)
for rating_summary in results:
   print(rating_summary)
# Out:
# {'_id': 'G', 'Movie count': 477}
# {'_id': 'M', 'Movie count': 37}
# {'_id': 'AO', 'Movie count': 3}
# {'_id': 'TV-Y7', 'Movie count': 3}
# {'_id': 'TV-G', 'Movie count': 59}
# {'_id': 'TV-MA', 'Movie count': 60}
# {'_id': 'TV-14', 'Movie count': 89}
# {'_id': 'PG-13', 'Movie count': 2321}
# {'_id': 'Not Rated', 'Movie count': 1}
# {'_id': 'OPEN', 'Movie count': 1}
# {'_id': 'R', 'Movie count': 5537}
# {'_id': 'PASSED', 'Movie count': 181}
# {'_id': 'GP', 'Movie count': 44}
# {'_id': 'PG', 'Movie count': 1852}
# {'_id': 'TV-PG', 'Movie count': 76}
# {'_id': None, 'Movie count': 9897}
# {'_id': 'Approved', 'Movie count': 5}
# {'_id': 'APPROVED', 'Movie count': 709}

# %% [markdown]
# ### Question 3
#
# Question: Count the number of movies with 3 comments or more.

# %% [markdown]
# **Answer:**

# %% [markdown]
# > Builds on the lesson's inner-join example: `$lookup` joins comments, `$addFields` computes a count per movie, `$match` filters to ≥3, and `$count` returns the total number of matching movies.

# %%
lookup_comments = {
    "$lookup": {
        "from": "comments",
        "localField": "_id",
        "foreignField": "movie_id",
        "as": "comments"
    }
}

add_comment_count = {
    "$addFields": {
        "comment_count": {"$size": "$comments"}
    }
}

match_comments = {
    "$match": {
        "comment_count": {"$gte": 3}
    }
}

count_movies = {
    "$count": "movies_gte_3"
}

pipeline = [
    lookup_comments,
    add_comment_count,
    match_comments,
    count_movies
]

result = list(movies.aggregate(pipeline))
print(result)
# Out:
# ---------------------------------------------------------------------------
# ExecutionTimeout                          Traceback (most recent call last)
# Cell In[16], line 33
#      22 count_movies = {
#      23     "$count": "movies_gte_3"
#      24 }
#      26 pipeline = [
#      27     lookup_comments,
#      28     add_comment_count,
#      29     match_comments,
#      30     count_movies
#      31 ]
# ---> 33 result = list(movies.aggregate(pipeline))
#      34 print(result)
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/synchronous/collection.py:3015, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2929 """Perform an aggregation using the aggregation framework on this
#    2930 collection.
#    2931
#    (...)   3012     https://mongodb.com/docs/manual/reference/command/aggregate
#    3013 """
#    3014 with self._database.client._tmp_session(session, close=False) as s:
# -> 3015     return self._aggregate(
#    3016         _CollectionAggregationCommand,
#    3017         pipeline,
#    3018         CommandCursor,
#    3019         session=s,
#    3020         explicit_session=session is not None,
#    3021         let=let,
#    3022         comment=comment,
#    3023         **kwargs,
#    3024     )
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/synchronous/collection.py:2913, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2902     kwargs["comment"] = comment
#    2903 cmd = aggregation_command(
#    2904     self,
#    2905     cursor_class,
#    (...)   2910     user_fields={"cursor": {"firstBatch": 1}},
#    2911 )
# -> 2913 return self._database.client._retryable_read(
#    2914     cmd.get_cursor,
#    2915     cmd.get_read_preference(session),  # type: ignore[arg-type]
#    2916     session,
#    2917     retryable=not cmd._performs_write,
#    2918     operation=_Op.AGGREGATE,
#    2919 )
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2047, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2042 # Ensure that the client supports retrying on reads and there is no session in
#    2043 # transaction, otherwise, we will not support retry behavior for this call.
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
# -> 2047 return self._retry_internal(
#    2048     func,
#    2049     session,
#    2050     None,
#    2051     operation,
#    2052     is_read=True,
#    2053     address=address,
#    2054     read_pref=read_pref,
#    2055     retryable=retryable,
#    2056     operation_id=operation_id,
#    2057 )
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2926, in _ClientConnectionRetryable._read(self)
#    2918 if self._retrying:
#    2919     _debug_log(
#    2920         _COMMAND_LOGGER,
#    2921         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)   2924         operationId=self._operation_id,
#    2925     )
# -> 2926 return self._func(self._session, self._server, conn, read_pref)
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/synchronous/aggregation.py:164, in _AggregationCommand.get_cursor(self, session, server, conn, read_preference)
#     161     write_concern = None
#     163 # Run command.
# --> 164 result = conn.command(
#     165     self._database.name,
#     166     cmd,
#     167     read_preference,
#     168     self._target.codec_options,
#     169     parse_write_concern_error=True,
#     170     read_concern=read_concern,
#     171     write_concern=write_concern,
#     172     collation=self._collation,
#     173     session=session,
#     174     client=self._database.client,
#     175     user_fields=self._user_fields,
#     176 )
#     178 if self._result_processor:
#     179     self._result_processor(result, conn)
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/synchronous/helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/synchronous/pool.py:413, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411     self._raise_if_not_writable(unacknowledged)
#     412 try:
# --> 413     return command(
#     414         self,
#     415         dbname,
#     416         spec,
#     417         self.is_mongos,
#     418         read_preference,
#     419         codec_options,  # type: ignore[arg-type]
#     420         session,
#     421         client,
#     422         check,
#     423         allowable_errors,
#     424         self.address,
#     425         listeners,
#     426         self.max_bson_size,
#     427         read_concern,
#     428         parse_write_concern_error=parse_write_concern_error,
#     429         collation=collation,
#     430         compression_ctx=self.compression_context,
#     431         use_op_msg=self.op_msg_enabled,
#     432         unacknowledged=unacknowledged,
#     433         user_fields=user_fields,
#     434         exhaust_allowed=exhaust_allowed,
#     435         write_concern=write_concern,
#     436     )
#     437 except (OperationFailure, NotPrimaryError):
#     438     raise
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/synchronous/network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pymongo/helpers_shared.py:280, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     278         timeout_details = _get_timeout_details(pool_opts)
#     279         errmsg += format_timeout_details(timeout_details)
# --> 280     raise ExecutionTimeout(errmsg, code, response, max_wire_version)
#     281 elif code == 43:
#     282     raise CursorNotFound(errmsg, code, response, max_wire_version)
#
# ExecutionTimeout: PlanExecutor error during aggregation :: caused by :: operation exceeded time limit, full error: {'ok': 0.0, 'errmsg': 'PlanExecutor error during aggregation :: caused by :: operation exceeded time limit', 'code': 50, 'codeName': 'MaxTimeMSExpired', '$clusterTime': {'clusterTime': Timestamp(1778598948, 22), 'signature': {'hash': b'\x0f\x8a4\x00\xdc\x015\xa6z[L\x8d\xc9\x8fq\xe6\x14\xeb63', 'keyId': 7594552994616573958}}, 'operationTime': Timestamp(1778598948, 22)}

# %%
# alternative 
comments = db.comments

pipeline = [
    {"$group": {"_id": "$movie_id", "comment_count": {"$sum": 1}}},
    {"$match": {"comment_count": {"$gte": 3}}},
    {"$count": "movies_gte_3"}
]

result = list(comments.aggregate(pipeline))
print(result)
# Out:
# [{'movies_gte_3': 400}]
